# %%
from urllib.request import Request, urlopen
import urllib.request
import requests
from bs4 import BeautifulSoup

# %%
user_name = "vatsal1999"

# %%
User_profile_url  = "https://www.codechef.com/users/{}".format(user_name)

# %%
User_page = requests.get(User_profile_url)
if str(User_page) == "<Response [404]>":
    print("Not OK")
else:
    print("Done")
# Out:
# Done
